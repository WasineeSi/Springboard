# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()

# %%
properties.head()

# %%
properties.index

# %%
properties = properties.reset_index()
properties.head()

# %%
properties.columns = properties.iloc[0]
properties.head()

# %%
properties = properties.tail(properties.shape[0] -1)
properties.head()

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties.columns

# %%
properties.rename(columns = {'Unnamed: 0':'Names'}, inplace = True)
properties.head()

# %%
properties.rename(columns={pd.NaT: "ID"}, inplace=True)
properties.head()

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties = pd.melt(properties, id_vars=['Names', 'ID'], var_name='Dates', value_name='avg_Price')

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties.dropna(how='any', inplace=True)
properties.reset_index(drop=True)

# %%
properties['avg_Price'] = pd.to_numeric(properties['avg_Price'])
print(properties.dtypes)

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
res = properties.notnull()
print(res)

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
properties['Dates'] = pd.to_datetime(properties['Dates'])
properties['Month'] = properties['Dates'].dt.month
properties['Year'] = properties['Dates'].dt.year

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
Brent_Only = properties[(properties['Names'] == 'Brent') & (properties['Year'] == 1995)]
Brent_Only.plot.line(x = 'Month', y = 'avg_Price', title = 'Month vs Average Price of Brent in 1995')

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(London_Borough):
    LB_1998 = properties[(properties['Names'] == London_Borough) & (properties['Year'] == 1998)]
    LB_2018 = properties[(properties['Names'] == London_Borough) & (properties['Year'] == 2018)]
    LB_avg_1998 = LB_1998['avg_Price'].mean()
    LB_avg_2018 = LB_2018['avg_Price'].mean()
    ratio = LB_avg_2018/LB_avg_1998
    print('The ratio in 2018 over 1998 of average price for ' + London_Borough + ' is ' + str(ratio))
    return ratio

# %%
def find_max_value(London_Borough):
    prop_Name = properties[(properties['Names'] == London_Borough) & (properties['Year'] == 2018)]
    max_value = (prop_Name['avg_Price'].max()) 
    print('The maximum value of the house in 2018 is ', str(max_value))
    return max_value

# %%
for index in properties.index:
    x = properties['Names'][index]
    print(x)
    find_max_value(x)
    create_price_ratio(x)
# Out:
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# ...
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974
# City of London
# The maximum value of the house in 2018 is  811694.19218
# The ratio in 2018 over 1998 of average price for City of London is 5.301620377587609
# Barking & Dagenham
# The maximum value of the house in 2018 is  302605.91693
# The ratio in 2018 over 1998 of average price for Barking & Dagenham is 4.89661861291754
# Barnet
# The maximum value of the house in 2018 is  541502.2221
# The ratio in 2018 over 1998 of average price for Barnet is 4.358195917538044
# Bexley
# The maximum value of the house in 2018 is  347531.06171
# The ratio in 2018 over 1998 of average price for Bexley is 4.248977046127877
# Brent
# The maximum value of the house in 2018 is  519753.71247
# The ratio in 2018 over 1998 of average price for Brent is 4.8945544971392865
# Bromley
# The maximum value of the house in 2018 is  449292.94154
# The ratio in 2018 over 1998 of average price for Bromley is 4.0947846853338765
# Camden
# The maximum value of the house in 2018 is  875078.3856
# The ratio in 2018 over 1998 of average price for Camden is 4.935353408884261
# Croydon
# The maximum value of the house in 2018 is  374361.1605
# The ratio in 2018 over 1998 of average price for Croydon is 4.201100280024767
# Ealing
# The maximum value of the house in 2018 is  485596.16581
# The ratio in 2018 over 1998 of average price for Ealing is 4.311450902121834
# Enfield
# The maximum value of the house in 2018 is  398208.0243
# The ratio in 2018 over 1998 of average price for Enfield is 4.26347158349581
# Greenwich
# The maximum value of the house in 2018 is  395920.29596
# The ratio in 2018 over 1998 of average price for Greenwich is 4.763036347329193
# Hackney
# The maximum value of the house in 2018 is  553833.342
# The ratio in 2018 over 1998 of average price for Hackney is 6.198285561008662
# Hammersmith & Fulham
# The maximum value of the house in 2018 is  738746.25027
# The ratio in 2018 over 1998 of average price for Hammersmith & Fulham is 4.137798101936229
# Haringey
# The maximum value of the house in 2018 is  560578.17685
# The ratio in 2018 over 1998 of average price for Haringey is 5.134624964136042
# Harrow
# The maximum value of the house in 2018 is  474510.2079
# The ratio in 2018 over 1998 of average price for Harrow is 4.0591964329643195
# Havering
# The maximum value of the house in 2018 is  373762.2815
# The ratio in 2018 over 1998 of average price for Havering is 4.325230371335308
# Hillingdon
# The maximum value of the house in 2018 is  416300.2936
# The ratio in 2018 over 1998 of average price for Hillingdon is 4.2002730803844575
# Hounslow
# The maximum value of the house in 2018 is  404184.2172
# The ratio in 2018 over 1998 of average price for Hounslow is 3.976409106143329
# Islington
# The maximum value of the house in 2018 is  677797.7384
# The ratio in 2018 over 1998 of average price for Islington is 4.844048012802298
# Kensington & Chelsea
# The maximum value of the house in 2018 is  1463377.921
# The ratio in 2018 over 1998 of average price for Kensington & Chelsea is 5.082465066092464
# Kingston upon Thames
# The maximum value of the house in 2018 is  511260.0465
# The ratio in 2018 over 1998 of average price for Kingston upon Thames is 4.270549521484271
# Lambeth
# The maximum value of the house in 2018 is  525074.6694
# The ratio in 2018 over 1998 of average price for Lambeth is 4.957751163514063
# Lewisham
# The maximum value of the house in 2018 is  417893.16032
# The ratio in 2018 over 1998 of average price for Lewisham is 5.449221041059685
# Merton
# The maximum value of the house in 2018 is  532751.8291
# The ratio in 2018 over 1998 of average price for Merton is 4.741273313294604
# Newham
# The maximum value of the house in 2018 is  368342.7819
# The ratio in 2018 over 1998 of average price for Newham is 5.305390437201879
# Redbridge
# The maximum value of the house in 2018 is  430707.82128
# The ratio in 2018 over 1998 of average price for Redbridge is 4.471182006097364
# Richmond upon Thames
# The maximum value of the house in 2018 is  677356.53881
# The ratio in 2018 over 1998 of average price for Richmond upon Thames is 4.005161895721457
# Southwark
# The maximum value of the house in 2018 is  518698.9561
# The ratio in 2018 over 1998 of average price for Southwark is 5.516485302379376
# Sutton
# The maximum value of the house in 2018 is  387410.10791
# The ratio in 2018 over 1998 of average price for Sutton is 4.118522608573157
# Tower Hamlets
# The maximum value of the house in 2018 is  464488.1465
# The ratio in 2018 over 1998 of average price for Tower Hamlets is 4.62670104006116
# Waltham Forest
# The maximum value of the house in 2018 is  447630.02054
# The ratio in 2018 over 1998 of average price for Waltham Forest is 5.83475580932281
# Wandsworth
# The maximum value of the house in 2018 is  605835.5744
# The ratio in 2018 over 1998 of average price for Wandsworth is 4.757709347739269
# Westminster
# The maximum value of the house in 2018 is  1117407.525
# The ratio in 2018 over 1998 of average price for Westminster is 5.353565392605413
# Inner London
# The maximum value of the house in 2018 is  580096.0743
# The ratio in 2018 over 1998 of average price for Inner London is 5.170857506254785
# Outer London
# The maximum value of the house in 2018 is  432351.75588
# The ratio in 2018 over 1998 of average price for Outer London is 4.418949809440314
# NORTH EAST
# The maximum value of the house in 2018 is  131244.5912
# The ratio in 2018 over 1998 of average price for NORTH EAST is 2.828080506434263
# NORTH WEST
# The maximum value of the house in 2018 is  163846.15457
# The ratio in 2018 over 1998 of average price for NORTH WEST is 3.3634156376540654
# YORKS & THE HUMBER
# The maximum value of the house in 2018 is  164087.50814
# The ratio in 2018 over 1998 of average price for YORKS & THE HUMBER is 3.356065086028382
# EAST MIDLANDS
# The maximum value of the house in 2018 is  194049.15621
# The ratio in 2018 over 1998 of average price for EAST MIDLANDS is 3.6327346720877034
# WEST MIDLANDS
# The maximum value of the house in 2018 is  196297.199
# The ratio in 2018 over 1998 of average price for WEST MIDLANDS is 3.3112621931400104
# EAST OF ENGLAND
# The maximum value of the house in 2018 is  294035.0438
# The ratio in 2018 over 1998 of average price for EAST OF ENGLAND is 4.166900547724156
# LONDON
# The maximum value of the house in 2018 is  484724.1072
# The ratio in 2018 over 1998 of average price for LONDON is 4.679776249632861
# SOUTH EAST
# The maximum value of the house in 2018 is  328060.73136
# The ratio in 2018 over 1998 of average price for SOUTH EAST is 3.8283877112840563
# SOUTH WEST
# The maximum value of the house in 2018 is  258838.52872
# The ratio in 2018 over 1998 of average price for SOUTH WEST is 3.795497124092444
# England
# The maximum value of the house in 2018 is  248619.94624
# The ratio in 2018 over 1998 of average price for England is 3.8104529783974

# %%
properties.loc[properties['avg_Price'].idxmax()]
# Out:
# Names        Kensington & Chelsea
# ID                      E09000020
# Dates         2018-01-01 00:00:00
# avg_Price             1463377.921
# Month                           1
# Year                         2018
# Name: 13267, dtype: object

# %% [markdown]
# # 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
